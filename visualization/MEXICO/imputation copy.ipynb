# %%
import pickle

import numpy as np
import torch
import pickle as pkl

is_sea = np.load("/home/mafzhang/data/MEXICO/8d/is_sea.npy")

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(3,7))
sns.set(style="whitegrid")
value = np.array([[0.2106, 0.2115, 0.2133, 0.2181, 0.2541],
                  [0.1724, 0.1787, 0.1877, 0.2039, 0.2598],
                  [0.1834, 0.1984, 0.2051, 0.2105, 0.2924],
                  [0.2219, 0.2219, 0.2219, 0.2219, 0.2219],
                  [0.0423, 0.0434, 0.0495, 0.0897, 0.2082],
                  [0.0686, 0.0758, 0.0797, 0.0885, 0.1348],
                  [0.0434, 0.0460, 0.0543, 0.0727, 0.1194]])
category = np.array(['Slide Window', "Lin-ITP", "TRMF", "Neural CF", "GRIN", "MAE", "Our"])
# value = value.reshape(-1)
# category = category.T
# category = category.reshape(-1)
color= sns.color_palette()[:7]
color = color[::-1]

# plot(x=category, y=value, showfliers=False)
plt.barh(category, value[:,4], color=color)
plt.yticks([])
plt.xticks(rotation=30,)
plt.tight_layout()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.ticker as mtick
from matplotlib.pyplot import MultipleLocator

sns.set(style="whitegrid")
figure = plt.figure(figsize=(3,7))
ax = figure.add_subplot(111)
value = np.array([[0.0764, 0.0770, 0.0784, 0.0823, 0.1175],
                  [0.0561, 0.0604, 0.0668, 0.0790, 0.1286],
                  [0.0602, 0.0695, 0.0744, 0.0790, 0.1640],
                  [0.0864, 0.0864, 0.0864, 0.0865, 0.0864],
                  [0.0046, 0.0050, 0.0067, 0.0178, 0.0746],
                  [0.0108, 0.0130, 0.0144, 0.0180, 0.0394],
                  [0.0048, 0.0053, 0.0073, 0.0126, 0.0285]])
category = np.array(['Slide Window', "Lin-ITP", "TRMF", "Neural CF", "GRIN", "MAE", "GraphDiff"])
# value = value.reshape(-1)
# category = category.T
# category = category.reshape(-1)

# plot(x=category, y=value, showfliers=False)
x_major_locator=MultipleLocator(0.03)
ax.xaxis.set_major_locator(x_major_locator)
ax.xaxis.set_major_formatter(mtick.FormatStrFormatter('%.2f'))
plt.barh(category, value[:,4], color=color)
plt.yticks([])
plt.xticks(rotation=30)
plt.tight_layout()
