# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# PRE

# %%
import pandas as pd
import numpy as np
missing = []
missing.append("10%")
missing.append("10%")
missing.append("30%")
missing.append("30%")
missing.append("50%")
missing.append("50%")
missing.append("70%")
missing.append("70%")
missing.append("90%")
missing.append("90%")
method = []
method.append("STIMP w/o TLT")
method.append("STIMP w/o HSGNN")
method.append("STIMP w/o TLT")
method.append("STIMP w/o HSGNN")
method.append("STIMP w/o TLT")
method.append("STIMP w/o HSGNN")
method.append("STIMP w/o TLT")
method.append("STIMP w/o HSGNN")
method.append("STIMP w/o TLT")
method.append("STIMP w/o HSGNN")
color_palette = ["#366AA1", "#DF2E2E"]
data = {'mae': -np.array([0.0115, 0.1236, 0.0293,0.1104,0.0493,0.1126,0.0858,0.0949,0.2677,0.1216]),
        'methods':method,
        'missing':missing}
data = pd.DataFrame.from_dict(data)
sns.barplot(data=data, x='missing',y='mae',hue="methods",palette=color_palette)
plt.xlabel(xlabel="missing rate", size=15)
plt.ylabel(ylabel="MAE", size=15)
# Out:
# Text(0, 0.5, 'MAE')

# %% [markdown]
# MEXICO

# %%
import pandas as pd
import numpy as np
missing = []
missing.append("10%")
missing.append("10%")
missing.append("30%")
missing.append("30%")
missing.append("50%")
missing.append("50%")
missing.append("70%")
missing.append("70%")
missing.append("90%")
missing.append("90%")
method = []
method.append("STIMP w/o TLT")
method.append("STIMP w/o HSGNN")
method.append("STIMP w/o TLT")
method.append("STIMP w/o HSGNN")
method.append("STIMP w/o TLT")
method.append("STIMP w/o HSGNN")
method.append("STIMP w/o TLT")
method.append("STIMP w/o HSGNN")
method.append("STIMP w/o TLT")
method.append("STIMP w/o HSGNN")
data = {'mae': -np.array([0.0041, 0.1032, 0.0165,0.1021,0.0319,0.0971,0.0655,0.0874,0.5209,0.1066]),
        'methods':method,
        'missing':missing}
data = pd.DataFrame.from_dict(data)
sns.barplot(data=data, x='missing',y='mae',hue="methods",palette=color_palette)
plt.xlabel(xlabel="missing rate", size=15)
plt.ylabel(ylabel="MAE", size=15)
# Out:
# Text(0, 0.5, 'MAE')

# %% [markdown]
# Chesapeake

# %%
import pandas as pd
import numpy as np
missing = []
missing.append("10%")
missing.append("10%")
missing.append("30%")
missing.append("30%")
missing.append("50%")
missing.append("50%")
missing.append("70%")
missing.append("70%")
missing.append("90%")
missing.append("90%")
method = []
method.append("STIMP w/o TLT")
method.append("STIMP w/o HSGNN")
method.append("STIMP w/o TLT")
method.append("STIMP w/o HSGNN")
method.append("STIMP w/o TLT")
method.append("STIMP w/o HSGNN")
method.append("STIMP w/o TLT")
method.append("STIMP w/o HSGNN")
method.append("STIMP w/o TLT")
method.append("STIMP w/o HSGNN")
print(len(method))
print(missing)
data = {'mae': -np.array([0.0039, 0.0634, 0.0105,0.0616,0.0217,0.0575,0.0418,0.0493,0.4221,0.0434]),
        'methods':method,
        'missing':missing}
data = pd.DataFrame.from_dict(data)
sns.barplot(data=data, x='missing',y='mae',hue="methods",palette=color_palette)
plt.xlabel(xlabel="missing rate", size=15)
plt.ylabel(ylabel="MAE", size=15)
# Out:
# 10
# ['10%', '10%', '30%', '30%', '50%', '50%', '70%', '70%', '90%', '90%']
# Text(0, 0.5, 'MAE')

# %% [markdown]
# Yangtze

# %%
import pandas as pd
import numpy as np
missing = []
missing.append("10%")
missing.append("10%")
missing.append("30%")
missing.append("30%")
missing.append("50%")
missing.append("50%")
missing.append("70%")
missing.append("70%")
missing.append("90%")
missing.append("90%")
method = []
method.append("STIMP w/o TLT")
method.append("STIMP w/o HSGNN")
method.append("STIMP w/o TLT")
method.append("STIMP w/o HSGNN")
method.append("STIMP w/o TLT")
method.append("STIMP w/o HSGNN")
method.append("STIMP w/o TLT")
method.append("STIMP w/o HSGNN")
method.append("STIMP w/o TLT")
method.append("STIMP w/o HSGNN")
print(len(method))
print(missing)
data = {'mae': -np.array([0.0098, 0.1177, 0.0256,0.1164,0.0545,0.1143,0.0886,0.1051,0.5632,0.0915]),
        'methods':method,
        'missing':missing}
data = pd.DataFrame.from_dict(data)
sns.barplot(data=data, x='missing',y='mae',hue="methods",palette=color_palette)
plt.xlabel(xlabel="missing rate", size=15)
plt.ylabel(ylabel="MAE", size=15)
# Out:
# 10
# ['10%', '10%', '30%', '30%', '50%', '50%', '70%', '70%', '90%', '90%']
# Text(0, 0.5, 'MAE')
